# %%
import pandas as pd
import sqlite3

# %%
conn=sqlite3.connect("factbook.db")
q="select * from facts limit 5"

# %%
pd.read_sql_query(q,conn)
# Out:
#    id code         name     area  area_land  area_water  population  \
# 0   1   af  Afghanistan   652230     652230           0    32564342
# 1   2   al      Albania    28748      27398        1350     3029278
# 2   3   ag      Algeria  2381741    2381741           0    39542166
# 3   4   an      Andorra      468        468           0       85580
# 4   5   ao       Angola  1246700    1246700           0    19625353
#
#    population_growth  birth_rate  death_rate  migration_rate
# 0               2.32       38.57       13.89            1.51
# 1               0.30       12.92        6.58            3.30
# 2               1.84       23.67        4.31            0.92
# 3               0.12        8.13        6.96            0.00
# 4               2.78       38.78       11.49            0.46

# %%
q="select min(population), max(population), min(population_growth), max(population_growth) from facts"

# %%
pd.read_sql_query(q,conn)
# Out:
#    min(population)  max(population)  min(population_growth)  \
# 0                0       7256490011                     0.0
#
#    max(population_growth)
# 0                    4.02

# %%
q="select name from facts where population=0"
pd.read_sql_query(q,conn)
# Out:
#          name
# 0  Antarctica

# %%
q="select name from facts where population=7256490011"
pd.read_sql_query(q,conn)
# Out:
#     name
# 0  World

# %% [markdown]
# `Antarctica` has lowest pop
# `World` has highest pop

# %%
q='''select population, population_growth, birth_rate, death_rate
from facts
where population != 0 and  population !=7256490011
'''
pd.read_sql_query(q,conn)
# Out:
#      population  population_growth  birth_rate  death_rate
# 0      32564342               2.32       38.57       13.89
# 1       3029278               0.30       12.92        6.58
# 2      39542166               1.84       23.67        4.31
# 3         85580               0.12        8.13        6.96
# 4      19625353               2.78       38.78       11.49
# 5         92436               1.24       15.85        5.69
# 6      43431886               0.93       16.64        7.33
# 7       3056382               0.15       13.61        9.34
# 8      22751014               1.07       12.15        7.14
# 9       8665550               0.55        9.41        9.42
# 10      9780780               0.96       16.64        7.07
# 11       324597               0.85       15.50        7.05
# 12      1346613               2.41       13.66        2.69
# 13    168957745               1.60       21.14        5.61
# 14       290604               0.31       11.87        8.44
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.read_sql_query(q,conn).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff17875d898>,
# ...
#       dtype=object)

# %%
pd.read_sql_query(q,conn)
# Out:
#      population  population_growth  birth_rate  death_rate
# 0      32564342               2.32       38.57       13.89
# 1       3029278               0.30       12.92        6.58
# 2      39542166               1.84       23.67        4.31
# 3         85580               0.12        8.13        6.96
# 4      19625353               2.78       38.78       11.49
# 5         92436               1.24       15.85        5.69
# 6      43431886               0.93       16.64        7.33
# 7       3056382               0.15       13.61        9.34
# 8      22751014               1.07       12.15        7.14
# 9       8665550               0.55        9.41        9.42
# 10      9780780               0.96       16.64        7.07
# 11       324597               0.85       15.50        7.05
# 12      1346613               2.41       13.66        2.69
# 13    168957745               1.60       21.14        5.61
# 14       290604               0.31       11.87        8.44
# ...

# %%
q='''select name, population/area from facts
where population != 0 and  population !=7256490011'''
pd.read_sql_query(q,conn).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff1783e8b70>]],
#       dtype=object)
